# %%
import os
from getpass import getpass

os.environ["GH_TOKEN"] = getpass("Paste GitHub token: ")
os.environ["HF_TOKEN"] = getpass("Paste Hugging Face token: ")

# %%
# %cd /content
# !rm -rf vnlegal-rag-v2
# !git clone https://${GH_TOKEN}@github.com/hyperformancelabs/vnlegal-rag-v2.git
# %cd vnlegal-rag-v2
# !pip install -e .
# Out:
# /content
# Cloning into 'vnlegal-rag-v2'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 632 (delta 107), reused 130 (delta 72), pack-reused 461 (from 1)
# Receiving objects: 100% (632/632), 121.48 MiB | 16.71 MiB/s, done.
# Resolving deltas: 100% (349/349), done.
# /content/vnlegal-rag-v2
# Obtaining file:///content/vnlegal-rag-v2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (0.13.2)
# Requirement already satisfied: pyvi in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (0.1.1)
# Requirement already satisfied: underthesea in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (9.5.0)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (5.5.1)
# Requirement already satisfied: bm25s in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (0.3.9)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (from vnlegal-rag-v2==0.1.0) (1.14.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (5.10.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.19.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (2.11.0+cu128)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (4.67.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu->vnlegal-rag-v2==0.1.0) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->vnlegal-rag-v2==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->vnlegal-rag-v2==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->vnlegal-rag-v2==0.1.0) (2026.2)
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.12/dist-packages (from pyvi->vnlegal-rag-v2==0.1.0) (0.5.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.12/dist-packages (from underthesea->vnlegal-rag-v2==0.1.0) (8.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from underthesea->vnlegal-rag-v2==0.1.0) (2.32.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from underthesea->vnlegal-rag-v2==0.1.0) (1.5.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from underthesea->vnlegal-rag-v2==0.1.0) (6.0.3)
# Requirement already satisfied: underthesea_core>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from underthesea->vnlegal-rag-v2==0.1.0) (3.3.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.29.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->vnlegal-rag-v2==0.1.0) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea->vnlegal-rag-v2==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea->vnlegal-rag-v2==0.1.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea->vnlegal-rag-v2==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea->vnlegal-rag-v2==0.1.0) (2026.5.20)
# Requirement already satisfied: python-crfsuite>=0.9.7 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi->vnlegal-rag-v2==0.1.0) (0.9.12)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi->vnlegal-rag-v2==0.1.0) (0.9.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.5.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers>=2.6.0->vnlegal-rag-v2==0.1.0) (0.1.2)
# Building wheels for collected packages: vnlegal-rag-v2
#   Building editable for vnlegal-rag-v2 (pyproject.toml) ... done
#   Created wheel for vnlegal-rag-v2: filename=vnlegal_rag_v2-0.1.0-0.editable-py3-none-any.whl size=1385 sha256=38ecd1ce46685f3e624b8a070e2cc76c7d8addfd187f997c57e6e3deb538aa7c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8jngs0mz/wheels/86/8f/16/c3124b4be639db7d2b065a5b714f123859ed3325b439347cad
# Successfully built vnlegal-rag-v2
# Installing collected packages: vnlegal-rag-v2
#   Attempting uninstall: vnlegal-rag-v2
#     Found existing installation: vnlegal-rag-v2 0.1.0
#     Uninstalling vnlegal-rag-v2-0.1.0:
#       Successfully uninstalled vnlegal-rag-v2-0.1.0
# Successfully installed vnlegal-rag-v2-0.1.0

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !gdown 1vkAnfAHNPEhu-aKrhR17RbyY3TYqXLzm
# !mkdir -p data/processed
# !unzip -o data_processed.zip -d data/processed
# !rm -rf data/processed/__MACOSX data_processed.zip
# !ls data/processed/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vkAnfAHNPEhu-aKrhR17RbyY3TYqXLzm
# From (redirected): https://drive.google.com/uc?id=1vkAnfAHNPEhu-aKrhR17RbyY3TYqXLzm&confirm=t&uuid=ea70fc81-3d97-42af-a65a-fff41d5d0ba1
# To: /content/vnlegal-rag-v2/data_processed.zip
# 100% 360M/360M [00:02<00:00, 125MB/s]
# Archive:  data_processed.zip
#   inflating: data/processed/corpus.csv
#   inflating: data/processed/corpus_pyvi.csv
#   inflating: data/processed/__MACOSX/._corpus_pyvi.csv
#   inflating: data/processed/train.csv
#   inflating: data/processed/eval.csv
#   inflating: data/processed/train_pyvi.csv
#   inflating: data/processed/eval_pyvi.csv
#   inflating: data/processed/train_underthesea.csv
#   inflating: data/processed/eval_underthesea.csv
#   inflating: data/processed/corpus_underthesea.csv
# corpus.csv		eval.csv	      train.csv
# corpus_pyvi.csv		eval_pyvi.csv	      train_pyvi.csv
# corpus_underthesea.csv	eval_underthesea.csv  train_underthesea.csv

# %%
# !pip install -U huggingface_hub
# !hf auth login --token ${HF_TOKEN}
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.19.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.2)
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# The token `base` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
for n in [5, 10, 15, 20]:
    # !python scripts/mine_negatives.py --config configs/data/negative_mining.yaml --num-negatives {n} --output data/processed/{n}_moderate_neg.csv
# Out:
# Loading weights: 100% 199/199 [00:00<00:00, 6369.07it/s]
# Batches: 100% 2049/2049 [29:19<00:00,  1.16it/s]
# Batches: 100% 940/940 [01:22<00:00, 11.45it/s]
# Mined 601020 negative pairs → data/processed/5_moderate_neg.csv
# Loading weights: 100% 199/199 [00:00<00:00, 6524.04it/s]
# Batches: 100% 2049/2049 [29:23<00:00,  1.16it/s]
# Batches: 100% 940/940 [01:22<00:00, 11.43it/s]
# Mined 1202040 negative pairs → data/processed/10_moderate_neg.csv
# Loading weights: 100% 199/199 [00:00<00:00, 6622.02it/s]
# Batches: 100% 2049/2049 [29:17<00:00,  1.17it/s]
# Batches: 100% 940/940 [01:21<00:00, 11.56it/s]
# Mined 1803060 negative pairs → data/processed/15_moderate_neg.csv
# Loading weights: 100% 199/199 [00:00<00:00, 6499.76it/s]
# Batches: 100% 2049/2049 [29:19<00:00,  1.16it/s]
# Batches: 100% 940/940 [01:21<00:00, 11.56it/s]
# Mined 2404080 negative pairs → data/processed/20_moderate_neg.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
for n in [5, 10, 15, 20]:
    f = f'data/processed/{n}_moderate_neg.csv'
    # !wc -l {f}
    # !head -2 {f}
    print()
# Out:
# 3833233 data/processed/5_moderate_neg.csv
# query,negative_text,negative_cid
# Người học ngành quản_lý khai_thác công_trình thủy_lợi trình_độ cao_đẳng phải có khả_năng học_tập và nâng cao_trình_độ như thế_nào ?,"Đối tượng quy định tại Khoản 1 Điều 1 Thông tư này, nếu chưa xếp bậc lương cuối cùng trong ngạch công chức (sau đây gọi là ngạch), trong chức danh nghề nghiệp viên chức, chức danh chuyên gia cao cấp và chức danh chuyên môn, nghiệp vụ ngành Tòa án, ngành Kiểm sát (sau đây gọi là chức danh) hiện giữ, thì được xét nâng một bậc lương thường xuyên khi có đủ điều kiện thời gian giữ bậc trong ngạch hoặc trong chức danh và đạt đủ tiêu chuẩn nâng bậc lương thường xuyên quy định tại Khoản 1 và Khoản 2 Điều này trong suốt thời gian giữ bậc lương như sau:
#
# 7664528 data/processed/10_moderate_neg.csv
# query,negative_text,negative_cid
# Người học ngành quản_lý khai_thác công_trình thủy_lợi trình_độ cao_đẳng phải có khả_năng học_tập và nâng cao_trình_độ như thế_nào ?,"Đối tượng quy định tại Khoản 1 Điều 1 Thông tư này, nếu chưa xếp bậc lương cuối cùng trong ngạch công chức (sau đây gọi là ngạch), trong chức danh nghề nghiệp viên chức, chức danh chuyên gia cao cấp và chức danh chuyên môn, nghiệp vụ ngành Tòa án, ngành Kiểm sát (sau đây gọi là chức danh) hiện giữ, thì được xét nâng một bậc lương thường xuyên khi có đủ điều kiện thời gian giữ bậc trong ngạch hoặc trong chức danh và đạt đủ tiêu chuẩn nâng bậc lương thường xuyên quy định tại Khoản 1 và Khoản 2 Điều này trong suốt thời gian giữ bậc lương như sau:
#
# 11480990 data/processed/15_moderate_neg.csv
# query,negative_text,negative_cid
# Người học ngành quản_lý khai_thác công_trình thủy_lợi trình_độ cao_đẳng phải có khả_năng học_tập và nâng cao_trình_độ như thế_nào ?,"Đối tượng quy định tại Khoản 1 Điều 1 Thông tư này, nếu chưa xếp bậc lương cuối cùng trong ngạch công chức (sau đây gọi là ngạch), trong chức danh nghề nghiệp viên chức, chức danh chuyên gia cao cấp và chức danh chuyên môn, nghiệp vụ ngành Tòa án, ngành Kiểm sát (sau đây gọi là chức danh) hiện giữ, thì được xét nâng một bậc lương thường xuyên khi có đủ điều kiện thời gian giữ bậc trong ngạch hoặc trong chức danh và đạt đủ tiêu chuẩn nâng bậc lương thường xuyên quy định tại Khoản 1 và Khoản 2 Điều này trong suốt thời gian giữ bậc lương như sau:
#
# 15324123 data/processed/20_moderate_neg.csv
# query,negative_text,negative_cid
# Người học ngành quản_lý khai_thác công_trình thủy_lợi trình_độ cao_đẳng phải có khả_năng học_tập và nâng cao_trình_độ như thế_nào ?,"Đối tượng quy định tại Khoản 1 Điều 1 Thông tư này, nếu chưa xếp bậc lương cuối cùng trong ngạch công chức (sau đây gọi là ngạch), trong chức danh nghề nghiệp viên chức, chức danh chuyên gia cao cấp và chức danh chuyên môn, nghiệp vụ ngành Tòa án, ngành Kiểm sát (sau đây gọi là chức danh) hiện giữ, thì được xét nâng một bậc lương thường xuyên khi có đủ điều kiện thời gian giữ bậc trong ngạch hoặc trong chức danh và đạt đủ tiêu chuẩn nâng bậc lương thường xuyên quy định tại Khoản 1 và Khoản 2 Điều này trong suốt thời gian giữ bậc lương như sau:

# %%
import os                                                 
                                                            
out_dir = '/content/drive/MyDrive/vnlegal-rag-v2/negatives'           
os.makedirs(out_dir, exist_ok=True)                       
                                                            
for n in [5, 10, 15, 20]:                                 
    src = f'data/processed/{n}_moderate_neg.csv'          
    dst = f'{out_dir}/{n}_moderate_neg.csv'               
    # !cp {src} {dst}                                       
    print(f'✓ {n}_moderate_neg.csv → {dst}')              
                                                            
print(f'\nAll files saved to {out_dir}')
# Out:
# ✓ 5_moderate_neg.csv → /content/drive/MyDrive/vnlegal-rag-v2/negatives/5_moderate_neg.csv
# ✓ 10_moderate_neg.csv → /content/drive/MyDrive/vnlegal-rag-v2/negatives/10_moderate_neg.csv
# ✓ 15_moderate_neg.csv → /content/drive/MyDrive/vnlegal-rag-v2/negatives/15_moderate_neg.csv
# ✓ 20_moderate_neg.csv → /content/drive/MyDrive/vnlegal-rag-v2/negatives/20_moderate_neg.csv
#
# All files saved to /content/drive/MyDrive/vnlegal-rag-v2/negatives
